# %% [markdown]
# <h2 align="center">Real State Assistant using RAG </h2>

# %%
# document loader

# %%
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader(file_path="patient_records.csv")

document = loader.load()
document[1]
# Out:
# Document(metadata={'source': 'patient_records.csv', 'row': 1}, page_content='patient_id: PT-1001\nsymptoms: Sharp back pain, numbness in legs\ndiagnosis: Herniated Disc\ntreatment: Physical therapy, pain management\ndoctor_notes: MRI suggested to confirm disc herniation.')

# %%
len(document)
# Out:
# 50

# %%
print(document[5].page_content)
# Out:
# patient_id: PT-1005
# symptoms: Abdominal pain, bloating, diarrhea
# diagnosis: Irritable Bowel Syndrome
# treatment: Diet changes, antispasmodic medication
# doctor_notes: IBS symptoms; recommend low FODMAP diet.

# %%
# !pip install unstructured

# %%
# unstructures url loder 
from langchain_community.document_loaders import UnstructuredURLLoader
loader = UnstructuredURLLoader(
    urls = ["https://reference.langchain.com/python/langchain-unstructured/document_loaders/UnstructuredLoader"]
)
docs = loader.load()
len(docs)
# Out:
# --------------------------------------------------
# ModuleNotFoundErrorTraceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_community\document_loaders\url.py:50, in UnstructuredURLLoader.__init__(self, urls, continue_on_failure, mode, show_progress_bar, **unstructured_kwargs)
#      49 try:
# ---> 50     import unstructured  # noqa:F401
#      51     from unstructured.__version__ import __version__ as __unstructured_version__
#
# ModuleNotFoundError: No module named 'unstructured'
#
# During handling of the above exception, another exception occurred:
#
# ImportError      Traceback (most recent call last)
# Cell In[13], line 3
#       1 # unstructures url loder
#       2 from langchain_community.document_loaders import  UnstructuredURLLoader
# ----> 3 loader = UnstructuredURLLoader(
#       4     urls = ["https://reference.langchain.com/python/langchain-unstructured/document_loaders/UnstructuredLoader"]
#       5 )
#       6 docs = loader.load()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_community\document_loaders\url.py:55, in UnstructuredURLLoader.__init__(self, urls, continue_on_failure, mode, show_progress_bar, **unstructured_kwargs)
#      53     self.__version = __unstructured_version__
#      54 except ImportError:
# ---> 55     raise ImportError(
#      56         "unstructured package not found, please install it with "
#      57         "`pip install unstructured`"
#      58     )
#      60 self._validate_mode(mode)
#      61 self.mode = mode
#
# ImportError: unstructured package not found, please install it with `pip install unstructured`

# %%
print(docs)
